# %%
import pandas as pd
import json
def get_latest_data(filename="latest.json"):
    f = open("%s"%filename,'r',encoding='utf-8')
    for line in f:
        dic=json.loads(line)
        Area = dic[ 'data' ]['listByArea']
        city=[]
        for i in Area:
            for j in i['cities']:
                cites_dict = {}
                cites_dict[ 'provinceName' ] = i[ 'provinceName' ]
                
                cites_dict[ 'provinceAbbreviation' ] = i[ 'provinceShortName' ]
                cites_dict[ 'city']= j['cityName']
                cites_dict[ 'confirmed']=j['confirmed']
                cites_dict[ 'suspected']=j['suspected']
                cites_dict[ 'cured']=j['cured']
                cites_dict[ 'dead']=j['dead']
                #解决重名
                if cites_dict['provinceAbbreviation']=="辽宁" and cites_dict['city']=="朝阳":
                    cites_dict['city']='辽宁朝阳'
                
                city.append(cites_dict)

        return pd.DataFrame(city)
def pushData():
    df=get_latest_data()
    df=df.applymap(lambda x: str(x))
    df=df.set_index("city")
    series = "确诊:" + df["confirmed"] + " 治愈:" + df["cured"] + " 死亡:" + df["dead"]
    return series


def updateData(old_series, new_series):
#     print("*" * 10)
#     print(new_series)
#     print("*" * 10)
#     print(old_series)
    update_list=[]
    old_cities=old_series.index
    new_cities=new_series.index
    print(len(old_cities))
    print(len(new_cities))
    diff_cities=list(set(new_cities)-set(old_cities))
    print(diff_cities)
    print("ln"*10)
    """
    """
    temp=list(old_cities)
    for i,j in zip(old_cities,new_cities):
        print(i,j)
    temp=set(temp)
    print(len(temp))
    print(len(new_series))
    temp=list(temp)
    temp=new_series[temp].index
    for i,j in zip(old_cities,temp):
        print(i,j)
    print(temp)
    print(old_series!=(new_series[list(old_cities)]))
    flag_list=(old_series!=new_series[list(old_cities)]).values
    print("1"*10)
    print(flag_list)
    if len(diff_cities)>0:
        update_list.extend(diff_cities)
    update_cities=(old_series[flag_list]).index
    print("ln1"*10)
    if len(update_cities)>0:
        update_list.extend(update_cities)
    print("eo"*10)
    print(update_cities)
    if len(update_cities)>0:
        return new_series[update_cities]
    else:
        return pd.Series()
series=pd.Series(["a"],["123"])
updateData(pushData(),pushData().append(series))
# Out:
# 308
# 309
# ['123']
# lnlnlnlnlnlnlnlnlnln
# 武汉 武汉
# 黄冈 黄冈
# 孝感 孝感
# 荆门 荆门
# 咸宁 咸宁
# 随州 随州
# 荆州 荆州
# 十堰 十堰
# 黄石 黄石
# 襄阳 襄阳
# 宜昌 宜昌
# 恩施州 恩施州
# 鄂州 鄂州
# 天门 天门
# 仙桃 仙桃
# 潜江 潜江
# 广州 广州
# 深圳 深圳
# 佛山 佛山
# 珠海 珠海
# 惠州 惠州
# 阳江 阳江
# 湛江 湛江
# 中山 中山
# 肇庆 肇庆
# 韶关 韶关
# 清远 清远
# 揭阳 揭阳
# 梅州 梅州
# 东莞 东莞
# 汕头 汕头
# 汕尾 汕尾
# 温州 温州
# 杭州 杭州
# 台州 台州
# 宁波 宁波
# 嘉兴 嘉兴
# 绍兴 绍兴
# 金华 金华
# 衢州 衢州
# 舟山 舟山
# 丽水 丽水
# 湖州 湖州
# 郑州 郑州
# 信阳 信阳
# 南阳 南阳
# 周口 周口
# 驻马店 驻马店
# 安阳市 安阳市
# 漯河 漯河
# 商丘 商丘
# 平顶山 平顶山
# 新乡 新乡
# 三门峡 三门峡
# 洛阳 洛阳
# 鹤壁 鹤壁
# 开封 开封
# 许昌 许昌
# 万州区 万州区
# 云阳县 云阳县
# 开州区 开州区
# 两江新区 两江新区
# 长寿区 长寿区
# 忠县 忠县
# 大渡口区 大渡口区
# 渝北区 渝北区
# 巫山县 巫山县
# 巫溪县 巫溪县
# 九龙坡区 九龙坡区
# 垫江县 垫江县
# 永川区 永川区
# 奉节县 奉节县
# 石柱县 石柱县
# 江北区 江北区
# 合川区 合川区
# 璧山区 璧山区
# 丰都县 丰都县
# 江津区 江津区
# 潼南区 潼南区
# 铜梁区 铜梁区
# 大足区 大足区
# 涪陵区 涪陵区
# 秀山县 秀山县
# 梁平区 梁平区
# 城口县 城口县
# 巴南区 巴南区
# 綦江区 綦江区
# 长沙 长沙
# 常德 常德
# 怀化 怀化
# 邵阳 邵阳
# 岳阳 岳阳
# 娄底 娄底
# 益阳 益阳
# 郴州 郴州
# 株洲 株洲
# 永州 永州
# 湘潭 湘潭
# 衡阳 衡阳
# 湘西自治州 湘西自治州
# 青岛 青岛
# 威海 威海
# 烟台 烟台
# 临沂 临沂
# 济南 济南
# 德州 德州
# 日照 日照
# 济宁 济宁
# 菏泽 菏泽
# ...

# %%
df=get_latest_data()

# %%
city_list=df["city"]

# %%
pushData()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-32b4fa5dfba0> in <module>()
# ----> 1 pushData()
#
# NameError: name 'pushData' is not defined

# %%
def func(x):
    result = ""
    for i in x:
        result+=i+" "
    return result
pro_to_cities=df[["provinceAbbreviation","city"]].groupby("provinceAbbreviation").agg(func)

# %%
for pro_to_cities["city"]["湖北"].split()
# Out:
# ['武汉',
#  '黄冈',
#  '孝感',
#  '荆门',
#  '咸宁',
#  '随州',
#  '荆州',
#  '十堰',
#  '黄石',
#  '襄阳',
#  '宜昌',
#  '恩施州',
#  '鄂州',
#  '天门',
#  '仙桃',
#  '潜江']

# %%
# Out:
# 308
# 309
# ['123']
# lnlnlnlnlnlnlnlnlnln
# 308
# 309
# 310
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ffd8a52447b9> in <module>()
#      43     else:
#      44         return pd.Series()
# ---> 45 updateData(pushData(),pushData().append(series))
#
# <ipython-input-14-ffd8a52447b9> in updateData(old_series, new_series)
#      27     print(len(new_series[temp]))
#      28
# ---> 29     print(old_series!=(new_series[list(old_cities)]))
#      30     flag_list=(old_series!=new_series[list(old_cities)]).values
#      31     print("1"*10)
#
# e:\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1140
#    1141         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1142             raise ValueError("Can only compare identically-labeled " "Series objects")
#    1143
# ...

# %% [markdown]
# ```
# Traceback (most recent call last):
#   File "sv_account.py", line 106, in <module>
#     threading.Thread(target=update_latest_data).start()#更新数据
#   File "sv_account.py", line 75, in main
#     new_series = pushData()
#   File "sv_account.py", line 53, in updateData
#     flag_list=(old_series!=new_series[old_cities]).values
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line
# 642, in __getitem__
#     return self._get_with(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line
# 685, in _get_with
#     return self.reindex(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line
# 2426, in reindex
#     return super(Series, self).reindex(index=index, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py", line
#  2404, in reindex
#     fill_value, copy).__finalize__(self)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py", line
#  2422, in _reindex_axes
#     copy=copy, allow_dups=False)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py", line
#  2516, in _reindex_with_indexers
#     copy=copy)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py", li
# ne 3886, in reindex_indexer
#     self.axes[axis]._can_reindex(indexer)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py",
#  line 2787, in _can_reindex
#     raise ValueError("cannot reindex from a duplicate axis")
# ValueError: cannot reindex from a duplicate axis
# ```

# %%
a = pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','a'])
print(a)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# a    6
# dtype: int64

# %%
a[['b','b']]
# Out:
# b    2
# b    2
# dtype: int64

# %%
series=pushData()

# %%
# Out:
# 123    a
# dtype: object

# %%
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-73893c957a48> in <module>()
#      44
#      45
# ---> 46 main()
#      47 get_latest_data()
#
# ~\Desktop\robot\whrbt\upload_latest_json.py in main()
#     143     data = Data(p)
#     144     while True:
# --> 145         time.sleep(5 + 10 * random.random())
#     146         response = load_response()
#     147         if response['data']['listByArea'] != data.response['data']['listByArea']:
#
# KeyboardInterrupt:
